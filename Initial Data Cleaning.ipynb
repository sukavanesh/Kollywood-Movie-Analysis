# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
dfx = pd.read_excel('D:\movie.xlsx')
dfx.head()
# Out:
#                       Movie_name            Movie_Lang_Genre_Cert  \
# 0  Kannum Kannum Kollaiyadithaal  | Tamil | Thriller, Romance | U
# 1                 Oh My Kadavule   | Tamil | Comedy, Romance | UA
# 2                         Psycho           | Tamil | Thriller | A
# 3                 Dharala Prabhu            | Tamil | Comedy | UA
# 4                          Gypsy             | Tamil | Drama | UA
#
#   Movie_Certification           Movie_Date_Runtime  \
# 0                   U   28 Feb 2020 | 2 hrs 2 mins
# 1                  UA  14 Feb 2020 | 2 hrs 31 mins
# 2                   A  24 Jan 2020 | 2 hrs 14 mins
# 3                  UA   13 Mar 2020 | 2 hrs 2 mins
# 4                  UA  06 Mar 2020 | 2 hrs 25 mins
#
#                                           Movie_Cast          Lead_Actor  \
# 0  Dulquer Salmaan, Ritu Varma, Gautham Vasudev M...     Dulquer Salmaan
# 1            Ashok Selvan, Ritika Singh, Vani Bhojan        Ashok Selvan
# ...

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
# Movie_name               300 non-null object
# Movie_Lang_Genre_Cert    300 non-null object
# Movie_Certification      300 non-null object
# Movie_Date_Runtime       300 non-null object
# Movie_Cast               299 non-null object
# Lead_Actor               235 non-null object
# Lead_Actress             230 non-null object
# Movie_Critic_Rating      300 non-null float64
# Movie_User_Rating        300 non-null float64
# Movie_Synopsis           297 non-null object
# dtypes: float64(2), object(8)
# memory usage: 23.6+ KB

# %%
dfx['Release'] = dfx['Movie_Date_Runtime'].apply(lambda x: x.split(' | ')[0])
dfx['Release']
# Out:
# 0      28 Feb 2020
# 1      14 Feb 2020
# 2      24 Jan 2020
# 3      13 Mar 2020
# 4      06 Mar 2020
#           ...
# 295    24 Jun 2011
# 296    09 Apr 2011
# 297    18 Feb 2011
# 298    14 Jan 2011
# 299    08 Apr 2011
# Name: Release, Length: 300, dtype: object

# %%
dfx['Runtime'] = dfx['Movie_Date_Runtime'].apply(lambda x: x.split(' | ')[1])
dfx['Runtime']
# Out:
# 0       2 hrs 2 mins
# 1      2 hrs 31 mins
# 2      2 hrs 14 mins
# 3       2 hrs 2 mins
# 4      2 hrs 25 mins
#            ...
# 295              Nan
# 296              Nan
# 297              Nan
# 298              Nan
# 299              Nan
# Name: Runtime, Length: 300, dtype: object

# %%
dfx.head()
# Out:
#                       Movie_name            Movie_Lang_Genre_Cert  \
# 0  Kannum Kannum Kollaiyadithaal  | Tamil | Thriller, Romance | U
# 1                 Oh My Kadavule   | Tamil | Comedy, Romance | UA
# 2                         Psycho           | Tamil | Thriller | A
# 3                 Dharala Prabhu            | Tamil | Comedy | UA
# 4                          Gypsy             | Tamil | Drama | UA
#
#   Movie_Certification           Movie_Date_Runtime  \
# 0                   U   28 Feb 2020 | 2 hrs 2 mins
# 1                  UA  14 Feb 2020 | 2 hrs 31 mins
# 2                   A  24 Jan 2020 | 2 hrs 14 mins
# 3                  UA   13 Mar 2020 | 2 hrs 2 mins
# 4                  UA  06 Mar 2020 | 2 hrs 25 mins
#
#                                           Movie_Cast          Lead_Actor  \
# 0  Dulquer Salmaan, Ritu Varma, Gautham Vasudev M...     Dulquer Salmaan
# 1            Ashok Selvan, Ritika Singh, Vani Bhojan        Ashok Selvan
# ...

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 12 columns):
# Movie_name               300 non-null object
# Movie_Lang_Genre_Cert    300 non-null object
# Movie_Certification      300 non-null object
# Movie_Date_Runtime       300 non-null object
# Movie_Cast               299 non-null object
# Lead_Actor               235 non-null object
# Lead_Actress             230 non-null object
# Movie_Critic_Rating      300 non-null float64
# Movie_User_Rating        300 non-null float64
# Movie_Synopsis           297 non-null object
# Release                  300 non-null object
# Runtime                  300 non-null object
# dtypes: float64(2), object(10)
# memory usage: 28.2+ KB

# %%
dfz = dfx.drop('Movie_Date_Runtime', axis=1)
dfz
# Out:
#                         Movie_name            Movie_Lang_Genre_Cert  \
# 0    Kannum Kannum Kollaiyadithaal  | Tamil | Thriller, Romance | U
# 1                   Oh My Kadavule   | Tamil | Comedy, Romance | UA
# 2                           Psycho           | Tamil | Thriller | A
# 3                   Dharala Prabhu            | Tamil | Comedy | UA
# 4                            Gypsy             | Tamil | Drama | UA
# ..                             ...                              ...
# 295                   Nootrenbadhu                        | Romance
# 296                 Ponnar Shankar                          | Drama
# 297               Nadunisi Naaygal                       | Thriller
# 298                       Ilaignan                          | Drama
# 299                      Mappillai                         | Comedy
#
#     Movie_Certification                                         Movie_Cast  \
# ...

# %%
'''dfz.to_excel('D:\moviev1.xlsx')'''
# Out:
# "dfz.to_excel('D:\\moviev1.xlsx')"
